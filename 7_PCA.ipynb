# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahulraj65-stack/MLDA/blob/main/7_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
x, y = load_iris(return_X_y=True)
x = StandardScaler().fit_transform(x)
x_pca = PCA(2).fit_transform(x)
plt.scatter(x_pca[:,0], x_pca[:,1], c=y)
plt.title("PCA of Iris"); plt.show()
